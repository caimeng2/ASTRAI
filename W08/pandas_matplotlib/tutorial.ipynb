# %% [markdown]
# # Input

# %%
import pandas as pd


# Load the DataFrame
df_1544 = pd.read_table('1544.csv', delimiter=';', encoding='latin-1', na_values="****")

# %%
df_1544.head()
# Out:
#   Zeit  1 - Standardmessrate     WI 1     WI 2     WI 3      WI 4     WI 5  \
# 0                          0  0,00018  -0,0004  0,04826  -0,00023   0,0012
# 1                0,020000001  0,00018  -0,0004  0,04826  -0,00023  0,00119
# 2                0,040000002  0,00017  -0,0004  0,04826  -0,00023  0,00118
# 3                0,060000003  0,00016  -0,0004  0,04827  -0,00024  0,00116
# 4                0,080000004  0,00014  -0,0004  0,04826  -0,00024  0,00115
#
#       WI 6     WI 7 Temperatur      WI 8 DMS - innen (200 mm)  \
# 0  0,00423  0,02444      23,68  -0,00197               -1,007
# 1  0,00424  0,02444      23,69  -0,00197               -1,012
# 2  0,00424  0,02443      23,69  -0,00197               -1,014
# 3  0,00424  0,02442      23,69  -0,00197               -1,015
# 4  0,00423  0,02441      23,69  -0,00197               -1,017
#
#   DMS - außen (350 mm)  PMX_1 CH 3-4  PMX_1 CH 4-1  PMX_1 CH 4-2  \
# 0                15,71      -1000000      -1000000      -1000000
# ...

# %% [markdown]
# # Convert the ,

# %%
# Define all potential columns that could need conversion
columns_to_convert = [
    'Zeit  1 - Standardmessrate', 'WI 1',
    'WI 2', 'WI 3',
    'WI 4', 'WI 5', 'WI 6',
    'WI 7', 'Temperatur', 'WI 8',
    'DMS - innen (200 mm)', 'DMS - außen (350 mm)', 'PMX_1 CH 3-4', 'PMX_1 CH 4-1', 'PMX_1 CH 4-2',
    'PMX_1 CH 4-3', 'PMX_1 CH 4-4', 'PMX_1 dig in', 'PMX_1 dig out'
]

# Convert columns
for column in columns_to_convert:
    df_1544[column] = df_1544[column].astype(str).str.replace(',', '.').astype(float)

df_1544.head()
# Out:
#    Zeit  1 - Standardmessrate     WI 1    WI 2     WI 3     WI 4     WI 5  \
# 0                        0.00  0.00018 -0.0004  0.04826 -0.00023  0.00120
# 1                        0.02  0.00018 -0.0004  0.04826 -0.00023  0.00119
# 2                        0.04  0.00017 -0.0004  0.04826 -0.00023  0.00118
# 3                        0.06  0.00016 -0.0004  0.04827 -0.00024  0.00116
# 4                        0.08  0.00014 -0.0004  0.04826 -0.00024  0.00115
#
#       WI 6     WI 7  Temperatur     WI 8  DMS - innen (200 mm)  \
# 0  0.00423  0.02444       23.68 -0.00197                -1.007
# 1  0.00424  0.02444       23.69 -0.00197                -1.012
# 2  0.00424  0.02443       23.69 -0.00197                -1.014
# 3  0.00424  0.02442       23.69 -0.00197                -1.015
# 4  0.00423  0.02441       23.69 -0.00197                -1.017
#
#    DMS - außen (350 mm)  PMX_1 CH 3-4  PMX_1 CH 4-1  PMX_1 CH 4-2  \
# 0                 15.71    -1000000.0    -1000000.0    -1000000.0
# ...

# %% [markdown]
# # Plot the figure

# %%
import matplotlib.pyplot as plt

# Ensure your DataFrame df_1544 is properly defined and the necessary columns have been converted to floats.

# Plotting the data from df_1544
plt.figure(figsize=(13, 8))

# Plot various 'WI' columns against the 'Zeit  1 - Standardmessrate' column.
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 5'], label='V_innen_r', color='blue')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 8'], label='V_außen_r', color='green')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 7'], label='H_Kopf_r', color='red')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 6'], label='H_Fuß_r', color='cyan')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 4'], label='V_außen_l', color='magenta')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 1'], label='V_innen_l', color='yellow')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 2'], label='H_Kopf_l', color='black')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 3'], label='H_Fuß_l', color='orange')

plt.title('Verschiebung über Zeit')
plt.xlabel("Zeit (s)")
plt.ylabel("Länge (mm)")
plt.legend()
plt.grid(True)

# Save the figure
plt.savefig('figure.png', dpi=300)

# Show it in Jupyter notebook
plt.show()

# %% [markdown]
# # Correct the offset errors

# %%
# Filter the DataFrame for the first 10 seconds
filtered_df = df_1544[df_1544['Zeit  1 - Standardmessrate'] <= 10]

# Calculate the mean of the 'WI 3' column within the first 10 seconds and adjust the column
mean_wi3 = filtered_df['WI 3'].mean()
df_1544['WI 3'] = df_1544['WI 3'] - mean_wi3
print("Mean of 'WI 3' for the first 10 seconds in df_1544:", mean_wi3)

# Calculate the mean of the 'WI 7' column within the first 10 seconds and adjust the column
mean_wi7 = filtered_df['WI 7'].mean()
df_1544['WI 7'] = df_1544['WI 7'] - mean_wi7
print("Mean of 'WI 7' for the first 10 seconds in df_1544:", mean_wi7)
# Out:
# Mean of 'WI 3' for the first 10 seconds in df_1544: 0.04829742
# Mean of 'WI 7' for the first 10 seconds in df_1544: 0.024538779999999996

# %% [markdown]
# # Plot the figure again

# %%
import matplotlib.pyplot as plt

# Ensure your DataFrame df_1544 is properly defined and the necessary columns have been converted to floats.

# Plotting the data from df_1544
plt.figure(figsize=(13, 8))

# Plot various 'WI' columns against the 'Zeit  1 - Standardmessrate' column.
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 5'], label='V_innen_r', color='blue')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 8'], label='V_außen_r', color='green')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 7'], label='H_Kopf_r', color='red')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 6'], label='H_Fuß_r', color='cyan')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 4'], label='V_außen_l', color='magenta')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 1'], label='V_innen_l', color='yellow')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 2'], label='H_Kopf_l', color='black')
plt.plot(df_1544['Zeit  1 - Standardmessrate'], df_1544['WI 3'], label='H_Fuß_l', color='orange')

plt.title('Verschiebung über Zeit')
plt.xlabel("Zeit (s)")
plt.ylabel("Länge (mm)")
plt.legend()
plt.grid(True)

# Save the figure
plt.savefig('figure_cleaned.png', dpi=300)

# Show it in Jupyter notebook
plt.show()

# %% [markdown]
# # Define upper and lower limits

# %%
# Define time limits for df_1544
lower_limit, upper_limit = (14.5, 28)

# Filter df_1544 for the specified time limits using the appropriate time column
# Assuming the time column is 'Zeit  1 - Standardmessrate'
df_filtered = df_1544[(df_1544['Zeit  1 - Standardmessrate'] >= lower_limit) & (df_1544['Zeit  1 - Standardmessrate'] <= upper_limit)]

# Plotting
plt.figure(figsize=(13, 8))
plt.plot(df_filtered['Zeit  1 - Standardmessrate'], df_filtered['WI 5'], label='V_innen_r', color='blue')
plt.plot(df_filtered['Zeit  1 - Standardmessrate'], df_filtered['WI 8'], label='V_außen_r', color='green')
plt.plot(df_filtered['Zeit  1 - Standardmessrate'], df_filtered['WI 7'], label='H_Kopf_r', color='red')
plt.plot(df_filtered['Zeit  1 - Standardmessrate'], df_filtered['WI 6'], label='H_Fuß_r', color='cyan')
plt.plot(df_filtered['Zeit  1 - Standardmessrate'], df_filtered['WI 4'], label='V_außen_l', color='magenta')
plt.plot(df_filtered['Zeit  1 - Standardmessrate'], df_filtered['WI 1'], label='V_innen_l', color='yellow')
plt.plot(df_filtered['Zeit  1 - Standardmessrate'], df_filtered['WI 2'], label='H_Kopf_l', color='black')
plt.plot(df_filtered['Zeit  1 - Standardmessrate'], df_filtered['WI 3'], label='H_Fuß_l', color='orange')

# Adding labels, title, legend, and grid
plt.title('Verschiebung über Zeit')
plt.xlabel("Zeit (s)")
plt.ylabel("Länge (mm)")
plt.legend()
plt.grid(True)

# Optionally save the figure
# plt.savefig('figure_cleaned_limits.png', dpi=300)

plt.show()
